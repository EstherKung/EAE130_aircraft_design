# %%
from TS_formulation import *

# %%
import numpy as np

# %%
(0.112-0.004*1.6) * np.sqrt(123)
# Out:
# np.float64(1.1711606550768345)

# %%
(7080-200-2500)*0.5
# Out:
# 2190.0

# %%
30064.36478660419 + 0.25 * 16047.494136323401 + 200 + (7080-200-2500)*0.5+2500
# Out:
# 38966.23832068504

# %%
6880 - 2500
# Out:
# 4380

# %%
 (7080-200)*0.5
# Out:
# 3440.0

# %%
0.25 * 16047.494136323401
# Out:
# 4011.8735340808503

# %%
W_fixed_payload
# Out:
# {'combat': 5240.0, 'strike': 7080.0, 'end': 7080.0}

# %%
weight_convergence(50000, T_0 = 29160, 
                                    S={'wing': 625, 'htail': 123.10441485216471, 'vtail': 107.19521577810403, 'fuse_wet': 702.3,}, 
                                    mission='strike')
# Out:
# 53191.8589229276 30064.36478660419 16047.494136323401
# (np.float64(53191.8589229276),
#  np.True_,
#  [(0, np.float64(51542.674650403016)),
#   (1, np.float64(52339.76078823139)),
#   (2, np.float64(52751.60803739191)),
#   (3, np.float64(52964.40581242687)),
#   (4, np.float64(53074.35651175078)),
#   (5, np.float64(53131.16705067597)),
#   (6, np.float64(53160.52054594991)),
#   (7, np.float64(53175.68723334803)),
#   (8, np.float64(53183.52372452176)),
#   (9, np.float64(53187.57276913539)),
#   (10, np.float64(53189.66487412468)),
#   (11, np.float64(53190.74584598444)),
#   (12, np.float64(53191.30437443669)),
#   (13, np.float64(53191.59296107208)),
#   (14, np.float64(53191.74207119492)),
#   (15, np.float64(53191.81911505631)),
#   (16, np.float64(53191.8589229276))])

# %%
fixed_payload(2*200, 2, 1, 0, 190, 228, 0, 2500)

# %%
W_FA18, _, _ = weight_convergence(66000, T_0 = 44000, 
                                    S={'wing': 500, 'htail': 88.0, 'vtail': 104.2, 'fuse_wet': 1200,}, 
                                    mission='strike')
W_FA18
# 66000

# %%
W_F35C, _, _ = weight_convergence(70000, T_0 = 43000, 
                                    S={'wing': 668, 'htail': 166.4, 'vtail': 102.7, 'fuse_wet': 1200,}, 
                                    mission='strike')
W_F35C
# 70000

# %%
W_F4, _, _ = weight_convergence(70000, T_0 = 35690, 
                                    S={'wing': 530, 'htail': 82.5, 'vtail': 60.2, 'fuse_wet': 1020,}, 
                                    mission='strike')
W_F4
# 60000
